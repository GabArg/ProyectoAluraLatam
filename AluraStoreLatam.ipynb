# %% [markdown]
# <a href="https://colab.research.google.com/github/GabArg/ProyectoAlluraLatam/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
# Calcular ingresos de cada tienda
ingresos_tienda1 = tienda['Precio'].sum()
ingresos_tienda2 = tienda2['Precio'].sum()
ingresos_tienda3 = tienda3['Precio'].sum()
ingresos_tienda4 = tienda4['Precio'].sum()

# Mostrar los ingresos por tienda
print(f"Ingresos de la Tienda 1: ${ingresos_tienda1:,.2f}")
print(f"Ingresos de la Tienda 2: ${ingresos_tienda2:,.2f}")
print(f"Ingresos de la Tienda 3: ${ingresos_tienda3:,.2f}")
print(f"Ingresos de la Tienda 4: ${ingresos_tienda4:,.2f}")

# Opcional: Total general
ingresos_totales = ingresos_tienda1 + ingresos_tienda2 + ingresos_tienda3 + ingresos_tienda4
print(f"Ingresos Totales: ${ingresos_totales:,.2f}")
# Out:
# Ingresos de la Tienda 1: $1,150,880,400.00
# Ingresos de la Tienda 2: $1,116,343,500.00
# Ingresos de la Tienda 3: $1,098,019,600.00
# Ingresos de la Tienda 4: $1,038,375,700.00
# Ingresos Totales: $4,403,619,200.00

# %% [markdown]
# # 2. Ventas por categoría

# %%
# Ingresos por categoría en Tienda 1
ingresos_categoria_tienda1 = tienda.groupby('Categoría del Producto')['Precio'].sum()
print("Ingresos por categoría en Tienda 1:")
print(ingresos_categoria_tienda1.to_string())
print("\n")

# Ingresos por categoría en Tienda 2
ingresos_categoria_tienda2 = tienda2.groupby('Categoría del Producto')['Precio'].sum()
print("Ingresos por categoría en Tienda 2:")
print(ingresos_categoria_tienda2.to_string())
print("\n")

# Ingresos por categoría en Tienda 3
ingresos_categoria_tienda3 = tienda3.groupby('Categoría del Producto')['Precio'].sum()
print("Ingresos por categoría en Tienda 3:")
print(ingresos_categoria_tienda3.to_string())
print("\n")

# Ingresos por categoría en Tienda 4
ingresos_categoria_tienda4 = tienda4.groupby('Categoría del Producto')['Precio'].sum()
print("Ingresos por categoría en Tienda 4:")
print(ingresos_categoria_tienda4.to_string())
print("\n")
# Out:
# Ingresos por categoría en Tienda 1:
# Categoría del Producto
# Artículos para el hogar     12698400.0
# Deportes y diversión        39290000.0
# Electrodomésticos          363685200.0
# Electrónicos               429493500.0
# Instrumentos musicales      91299000.0
# Juguetes                    17995700.0
# Libros                       8784900.0
# Muebles                    187633700.0
#
#
# Ingresos por categoría en Tienda 2:
# Categoría del Producto
# Artículos para el hogar     14746900.0
# Deportes y diversión        34744500.0
# Electrodomésticos          348567800.0
# Electrónicos               410831100.0
# Instrumentos musicales     104990300.0
# Juguetes                    15945400.0
# Libros                      10091200.0
# Muebles                    176426300.0
#
#
# Ingresos por categoría en Tienda 3:
# Categoría del Producto
# Artículos para el hogar     15060000.0
# Deportes y diversión        35593100.0
# Electrodomésticos          329237900.0
# ...

# %%
# Función para graficar ingresos por categoría de producto
def graficar_ingresos_categoria(tienda, tienda_nombre):
    # Calcular los ingresos por categoría
    ingresos_categoria = tienda.groupby('Categoría del Producto')['Precio'].sum().reset_index()

    # Crear gráfico de barras
    plt.figure(figsize=(10, 6))
    sns.barplot(data=ingresos_categoria, x='Categoría del Producto', y='Precio', palette="viridis", legend=False)
    plt.title(f'Ingresos por Categoría de Producto en {tienda_nombre}')
    plt.xlabel('Categoría del Producto')
    plt.ylabel('Ingresos ($)')
    plt.xticks(rotation=45, ha='right')  # Rotar etiquetas para mejor visibilidad
    plt.tight_layout()
    plt.show()

# Para Tienda 1
graficar_ingresos_categoria(tienda, 'Tienda 1')

# Para Tienda 2
graficar_ingresos_categoria(tienda2, 'Tienda 2')

# Para Tienda 3
graficar_ingresos_categoria(tienda3, 'Tienda 3')

# Para Tienda 4
graficar_ingresos_categoria(tienda4, 'Tienda 4')
# Out:
# <ipython-input-19-593836e73413>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ingresos_categoria, x='Categoría del Producto', y='Precio', palette="viridis", legend=False)
# <ipython-input-19-593836e73413>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ingresos_categoria, x='Categoría del Producto', y='Precio', palette="viridis", legend=False)
# <ipython-input-19-593836e73413>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Función para calcular el promedio de calificación de toda la tienda con 2 decimales
def promedio_tienda(tienda, tienda_num):
    promedio = tienda['Calificación'].mean()
    print(f"Promedio general de calificación para la Tienda {tienda_num}: {promedio:.2f}")

# Calcular el promedio para cada tienda
promedio_tienda(tienda1, 1)
promedio_tienda(tienda2, 2)
promedio_tienda(tienda3, 3)
promedio_tienda(tienda4, 4)
# Out:
# Promedio general de calificación para la Tienda 1: 3.98
# Promedio general de calificación para la Tienda 2: 4.04
# Promedio general de calificación para la Tienda 3: 4.05
# Promedio general de calificación para la Tienda 4: 4.00

# %%
import matplotlib.pyplot as plt

# Calcular los promedios de calificación para cada tienda
promedios = [
    tienda1['Calificación'].mean(),
    tienda2['Calificación'].mean(),
    tienda3['Calificación'].mean(),
    tienda4['Calificación'].mean()
]

# Etiquetas para las tiendas
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# Crear el gráfico de barras
plt.figure(figsize=(8, 5))
plt.bar(tiendas, promedios, color=['skyblue', 'lightgreen', 'salmon', 'gold'], alpha=0.8)

# Personalizar el gráfico
plt.title('Promedio de Calificaciones por Tienda', fontsize=14)
plt.ylabel('Calificación Promedio', fontsize=12)
plt.xlabel('Tiendas', fontsize=12)
plt.ylim(0, 5)  # Las calificaciones están entre 0 y 5
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Mostrar las calificaciones sobre las barras
for i, promedio in enumerate(promedios):
    plt.text(i, promedio + 0.1, f"{promedio:.2f}", ha='center', fontsize=10)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Productos más y menos vendidos por tienda
def productos_mas_y_menos_vendidos(df, nombre_tienda):
    # Contar las ocurrencias de cada producto
    productos_vendidos = df['Producto'].value_counts()
    # Determinar el producto más vendido
    producto_mas_vendido = productos_vendidos.idxmax()
    cantidad_mas_vendida = productos_vendidos.max()
    # Determinar el producto menos vendido
    producto_menos_vendido = productos_vendidos.idxmin()
    cantidad_menos_vendida = productos_vendidos.min()

    print(f"\n{nombre_tienda}:")
    print(f"Producto más vendido: {producto_mas_vendido} ({cantidad_mas_vendida} ventas)")
    print(f"Producto menos vendido: {producto_menos_vendido} ({cantidad_menos_vendida} ventas)")

# Aplicar a cada tienda
productos_mas_y_menos_vendidos(tienda1, "Tienda 1")
productos_mas_y_menos_vendidos(tienda2, "Tienda 2")
productos_mas_y_menos_vendidos(tienda3, "Tienda 3")
productos_mas_y_menos_vendidos(tienda4, "Tienda 4")
# Out:
# Tienda 1:
# Producto más vendido: Microondas (60 ventas)
# Producto menos vendido: Auriculares con micrófono (33 ventas)
#
# Tienda 2:
# Producto más vendido: Iniciando en programación (65 ventas)
# Producto menos vendido: Juego de mesa (32 ventas)
#
# Tienda 3:
# Producto más vendido: Kit de bancas (57 ventas)
# Producto menos vendido: Bloques de construcción (35 ventas)
#
# Tienda 4:
# Producto más vendido: Cama box (62 ventas)
# Producto menos vendido: Guitarra eléctrica (33 ventas)

# %%
import matplotlib.pyplot as plt

def graficar_top_productos_vendidos(df, nombre_tienda):
    # Contar los productos vendidos
    productos_vendidos = df['Producto'].value_counts()

    # Obtener los 5 más vendidos y 5 menos vendidos
    top_5_mas_vendidos = productos_vendidos.head(5)
    top_5_menos_vendidos = productos_vendidos.tail(5)

    # Crear subplots
    fig, axs = plt.subplots(1, 2, figsize=(14, 6), gridspec_kw={'width_ratios': [1, 1]})

    # Gráfico de los más vendidos
    axs[0].bar(top_5_mas_vendidos.index, top_5_mas_vendidos.values, color='green', edgecolor='black')
    axs[0].set_title(f"Top 5 Más Vendidos - {nombre_tienda}", fontsize=14)
    axs[0].set_xlabel("Producto", fontsize=12)
    axs[0].set_ylabel("Cantidad Vendida", fontsize=12)
    axs[0].tick_params(axis='x', rotation=45, labelsize=10)
    axs[0].grid(axis='y', linestyle='--', alpha=0.7)

    # Gráfico de los menos vendidos
    axs[1].bar(top_5_menos_vendidos.index, top_5_menos_vendidos.values, color='red', edgecolor='black')
    axs[1].set_title(f"Top 5 Menos Vendidos - {nombre_tienda}", fontsize=14)
    axs[1].set_xlabel("Producto", fontsize=12)
    axs[1].set_ylabel("Cantidad Vendida", fontsize=12)
    axs[1].tick_params(axis='x', rotation=45, labelsize=10)
    axs[1].grid(axis='y', linestyle='--', alpha=0.7)

    plt.tight_layout()
    plt.show()

# Aplicar a cada tienda
graficar_top_productos_vendidos(tienda1, "Tienda 1")
graficar_top_productos_vendidos(tienda2, "Tienda 2")
graficar_top_productos_vendidos(tienda3, "Tienda 3")
graficar_top_productos_vendidos(tienda4, "Tienda 4")

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
# Calcular el costo de envío promedio por tienda
envio_promedio_por_tienda = {
    "Tienda 1": tienda1['Costo de envío'].mean(),
    "Tienda 2": tienda2['Costo de envío'].mean(),
    "Tienda 3": tienda3['Costo de envío'].mean(),
    "Tienda 4": tienda4['Costo de envío'].mean(),
}

# Mostrar los resultados con dos decimales
for tienda, costo_promedio in envio_promedio_por_tienda.items():
    print(f"{tienda}: ${costo_promedio:,.2f}")
# Out:
# Tienda 1: $26,018.61
# Tienda 2: $25,216.24
# Tienda 3: $24,805.68
# Tienda 4: $23,459.46

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Suponiendo que ya tienes los DataFrames de cada tienda (tienda1, tienda2, tienda3, tienda4)
# Si no, realiza la división según tu lógica anterior

# Calcular el envío promedio por tienda
envio_promedio_tienda1 = tienda1['Costo de envío'].mean()
envio_promedio_tienda2 = tienda2['Costo de envío'].mean()
envio_promedio_tienda3 = tienda3['Costo de envío'].mean()
envio_promedio_tienda4 = tienda4['Costo de envío'].mean()

# Datos para el gráfico circular (envíos promedio por tienda)
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
envios_promedio = [envio_promedio_tienda1, envio_promedio_tienda2, envio_promedio_tienda3, envio_promedio_tienda4]

# Crear el gráfico circular
plt.figure(figsize=(8, 8))
plt.pie(envios_promedio, labels=tiendas, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
plt.title('Envíos Promedio por Tienda')

# Mostrar el gráfico
plt.axis('equal')  # Para asegurar que el gráfico sea un círculo
plt.show()

# %% [markdown]
# **Informe Final: Análisis de Tiendas y Recomendación para el Sr. Juan**
#
# **Introducción**
#
# El objetivo de este análisis es identificar cuál de las tiendas evaluadas es la menos eficiente, basándonos en diversos factores clave como los ingresos totales, las categorías de productos más y menos vendidas, las calificaciones promedio de los clientes, los productos más y menos vendidos, y el coste de envío promedio. La tienda menos eficiente representa una oportunidad para el Sr. Juan de enfocarse en mejorar su rendimiento, ya sea optimizando operaciones o realizando ajustes en la estrategia comercial.
#
#
# **Desarrollo**
#
# **Ingresos Totales de las Tiendas**
#
# A continuación se presentan los ingresos totales de cada tienda:
#
# Tienda 1: $1,150,880,400.00
#
# Tienda 2: $1,116,343,500.00
#
# Tienda 3: $1,098,019,600.00
#
# Tienda 4: $1,038,375,700.00
#
# Aunque la Tienda 4 tiene los ingresos más bajos, lo que podría sugerir un rendimiento inferior, es importante recordar que los ingresos no son el único indicador de eficiencia.
#
#
# **Calificación Promedio de los Clientes**
#
# Las calificaciones promedio de los clientes son importantes para evaluar la satisfacción y lealtad:
#
# Tienda 1: 3.98
#
# Tienda 2: 4.04
#
# Tienda 3: 4.05
#
# Tienda 4: 4.00
#
# La Tienda 3 es la que recibe las mejores calificaciones, lo que indica que sus clientes están más satisfechos. En cambio, la Tienda 1 tiene la calificación más baja, lo que podría sugerir que los clientes no están completamente satisfechos con su experiencia de compra.
#
# **Costos de Envío Promedio**
#
# Los costos de envío promedio son un indicador importante de los gastos operativos y la rentabilidad de la tienda:
#
# Tienda 1: $26,018.61
#
# Tienda 2: $25,216.24
#
# Tienda 3: $24,805.68
#
# Tienda 4: $23,459.46
#
# Aunque la Tienda 4 tiene el costo de envío más bajo, esto no necesariamente refleja una mayor eficiencia operativa. Un costo bajo podría estar relacionado con un servicio logístico deficiente. La Tienda 1, por otro lado, tiene un costo de envío elevado, lo que podría estar afectando la rentabilidad de la tienda.
#
# **Productos Más y Menos Vendidos**
#
# Los productos más vendidos en cada tienda indican qué tan bien se están posicionando sus productos en el mercado:
#
# Tienda 1: Microondas (60 ventas) vs Auriculares con micrófono (33 ventas)
#
# Tienda 2: Iniciando en programación (65 ventas) vs Juego de mesa (32 ventas)
#
# Tienda 3: Kit de bancas (57 ventas) vs Bloques de construcción (35 ventas)
#
# Tienda 4: Cama box (62 ventas) vs Guitarra eléctrica (33 ventas)
#
# Aunque las diferencias en los productos más y menos vendidos no son tan extremas, la Tienda 2 tiene el producto menos vendido (Juego de mesa) con un número bajo de ventas (32 ventas), lo que podría indicar que no está logrando un buen desempeño en términos de ventas por producto.
#
# **Conclusión y Recomendación**
#
# **Tienda menos eficiente: Tienda 4**
#
# A pesar de que la Tienda 4 tiene un costo de envío más bajo, es la que menos ingresos genera. En conjunto con una calificación de clientes moderada (4.00), esto indica que no está alcanzando su máximo potencial. Otros factores como el desempeño de sus productos también sugieren que no está tan bien posicionada en el mercado como las otras tiendas.
#
# Razones para vender la Tienda 4:
#
# **Menores ingresos:** La Tienda 4 tiene los ingresos más bajos entre todas, lo que sugiere que su rentabilidad es inferior a las demás.
#
# **Satisfacción del cliente moderada:** Aunque su calificación no es la peor, está por debajo de otras tiendas que tienen una calificación de 4.05 (Tienda 3).
#
# **Costos de envío más bajos, pero con ingresos reducidos:** El bajo costo de envío podría ser un indicio de operaciones logísticas ineficientes, lo que afecta la rentabilidad general.
#
# **Desempeño de productos:** Aunque tiene un producto más vendido, los productos menos vendidos también están en una posición débil, con una baja cantidad de ventas.
#
# **Recomendación Final:** Se recomienda que el Sr. Juan venda la Tienda 4. Con los ingresos más bajos, la satisfacción del cliente más moderada y una rentabilidad subóptima, vender esta tienda permitiría abrir una nueva tienda con mayores oportunidades de éxito y rentabilidad.
